# %%
#-1: Setting up google colab:
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# %cd '/content/gdrive/My Drive/CS6910_DL/a4/'
# !ls
#!unzip data.zip
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/CS6910_DL/a4
# a4_1.ipynb  a4_2.ipynb	data	  features2.pkl  models
# a4_1.py     a4_2.py	data.zip  features.pkl

# %%
#0. Importing modules & defining global variables:
import os
import csv
import pickle
import random
import string
import numpy as np 
import pandas as pd
import seaborn as sns
import tensorflow as tf 
from sklearn import metrics
from tensorflow import keras
from matplotlib import pyplot as plot 
from tensorflow.keras import backend as bk
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import *
from tensorflow.keras.preprocessing.image import *
from tensorflow.keras.preprocessing.sequence import pad_sequences
print(tf.__version__)

dir='./data/data1/'
out_vgg16=4096
K,D=4,3
val_split,max_patience,batchsize,max_epochs=0.1,5,2,100
# Out:
# 2.3.0

# %%
#1. Image pre-processing functions:
def req_images(images='Test_image.txt'):  #'image_names.txt'):
    with open(dir+images) as f:
        reader=csv.reader(f,delimiter="\t")
        image_filename=list(reader)
    image_filenames=np.concatenate(image_filename)
    return image_filenames

def image_featurizer(sub_dir='Images',out_pkl='features1.pkl',j_limit=4):  #features.pkil==(4096), features2.pkl==(7,7,512) of vgg16; j_limit=10k.
    features,j=dict(),0
    model1=keras.applications.VGG16()
    model1._layers.pop()
    model1._layers.pop()
    model=keras.models.Model(inputs=model1.inputs, outputs=model1.layers[-3].output)
    model.summary()
    for filename in os.listdir(dir+sub_dir+'/'):
        j=j+1
        if j>j_limit:
            break
        print('Reading ',j,'.',filename,'...')
        img=img_to_array(load_img(dir+'Images/'+filename,target_size=(224,224)))
        img=img.reshape((1,img.shape[0],img.shape[1],img.shape[2]))
        img=keras.applications.vgg16.preprocess_input(img)
        features[filename]=model.predict(img,verbose=0)
    print('Extracted Features: ',len(features))
#    pickle.dump(features, open(out_pkl, 'wb'))

def load_photo_features(dataset,filename='features2.pkl'):
    all_features,features,j = pickle.load(open(filename, 'rb')),dict(),0
    for key, value in all_features.items():
        if key in dataset:
            j=j+1
            print('Reading features of ',j,'.',key,'...')
            features[key]=value
#	features = {k: all_features[k] for k in dataset}
    return features

# %%
#2. Text pre-processing functions:
def to_vocabulary(descriptions):
	vocab = set()
	for key in descriptions.keys():
		[vocab.update(d.split()) for d in descriptions[key]]
	return vocab

def text_extractor(image_filenames,captions='captions.txt'):
	mapping,table,j = dict(),str.maketrans('', '', string.punctuation),0
	print('Total of ',len(image_filenames),' unique images to be read!')
	with open(dir+captions) as f:
		reader=csv.reader(f,delimiter="\t")
		captions_data=list(reader)
	for i in range(len(captions_data)):
		image_filename=str.split(str.split(captions_data[i][0],'#')[0],'.1')[0]
		if image_filename in image_filenames:
			j=j+1
			print('Reading captions of ',j,'.',image_filename,'...')
			if image_filename not in mapping.keys():
				mapping[image_filename]=[]
			description=captions_data[i][1].split()
			description=[word.lower() for word in description]
			description=[word.translate(table) for word in description]
			description=[word for word in description if len(word)>1 and word.isalpha()]
			mapping[image_filename].append('startseq ' + ' '.join(description) + ' endseq')
	print('Length of vocabulary: ',len(to_vocabulary(mapping)))
	return mapping

def all_desc(descriptions):
	all_descriptions = list()
	for key in descriptions.keys():
		[all_descriptions.append(d) for d in descriptions[key]]
	return all_descriptions

def max_len(descriptions):
	lines = all_desc(descriptions)
	return max(len(d.split()) for d in lines)
 
def create_tokenizer(descriptions):
	lines = all_desc(descriptions)
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

def data_generator1(descriptions, photos, tokenizer, max_length, vocab_size):
	# loop for ever over images
	while 1:
		for key, desc_list in descriptions.items():
			# retrieve the photo feature
			photo = photos[key][0]
			in_img, in_seq, out_word = create_sequences(tokenizer, max_length, desc_list, photo, vocab_size)
			yield [[in_img, in_seq], out_word]
def data_generator(descriptions, photos, tokenizer, max_length, vocab_size):
	while 1:
		for key, desc in descriptions.items():
			if key in photos.keys():
				photo = photos[key][0]
				in_img, in_seq, out_word = create_sequences(tokenizer, max_length, desc, photo, vocab_size)
				yield [[in_img, in_seq], out_word]

# %%
class DataGenerator(keras.utils.Sequence):
    def __init__(self, descriptions, tokenizer, max_length, photos, vocab_size, batch_size=2, shuffle=True):
        self.descriptions=descriptions
        self.batch_size = batch_size
        self.tokenizer=tokenizer
        self.max_length=max_length
        self.photos=photos
        self.vocab_size=vocab_size
        self.list_IDs = list(self.descriptions.keys())
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        X, y = self.__data_generation(list_IDs_temp)
        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        desc=dict()
        for i, ID in enumerate(list_IDs_temp):
            desc[ID]=self.descriptions[ID]
        return create_sequences(self.tokenizer,self.max_length,desc,self.photos,self.vocab_size)

# %%
#3. Classes & functions for building model:
class NetVLADLayer(tf.keras.layers.Layer):
	def __init__(self,num_clusters,**kwargs):
		self.K = num_clusters
		super(NetVLADLayer,self).__init__(**kwargs)

	def build(self,input_shape):
		self.D = input_shape[-1]
		self.kernel = self.add_weight(shape=(1,1,self.D,self.K),initializer='GlorotUniform',trainable=True,name='alpha')
		self.bias = self.add_weight(shape=(1,1,self.K),initializer='uniform',trainable=True,name='bias')
		self.C = self.add_weight(shape=[1,1,1,self.D,self.K],initializer='GlorotUniform',trainable=True,name='beta')
		super(NetVLADLayer,self).build(input_shape)  

	def call(self,x):
		input_shape = tf.shape(x)
		a = bk.expand_dims(bk.softmax(bk.conv2d(x,self.kernel,strides=(1,1),padding='same')+self.bias),-2)
		z_k = a * (bk.expand_dims(x,-1)+self.C)
		z = bk.sum(z_k, axis=[1, 2])
		z = bk.permute_dimensions(z, pattern=[0, 2, 1])
		z = bk.l2_normalize(z,axis=-1)
		z = bk.batch_flatten(z)
		z = bk.l2_normalize(z,axis=-1)
		return tf.reshape(z, self.compute_output_shape(input_shape))

	def compute_output_shape(self,input_shape):
		return (input_shape[0],self.K*self.D)

	def get_config(self):
		pass
		config = {'num_clusters': self.K}
		base_config = super(NetVLADLayer, self).get_config()
		return dict(list(base_config.items()) + list(config.items()))

def build_model(vocab_size,max_length,inp_shape,K=0,drop=0.5,d1=256,embed=256,lstm=256,d2=256):
	input1=keras.Input(shape=inp_shape)
	input2=keras.Input(shape=(max_length,))
	netvlad1=NetVLADLayer(K)
	drop1=keras.layers.Dropout(drop)
	dense1=keras.layers.Dense(d1, activation='softmax')
	embed1=keras.layers.Embedding(vocab_size,embed,mask_zero=True)#
	lstm1=keras.layers.LSTM(lstm)  #,return_sequences=True)
	dense2=keras.layers.Dense(d2,activation='relu')
	dense3=keras.layers.Dense(vocab_size,activation='softmax')

	out_netvlad1=netvlad1(input1)
	out_dense1=dense1(out_netvlad1)
	out_embed1=embed1(input2)
	out_lstm1=lstm1(out_embed1)
	out_merge1=keras.layers.concatenate([out_lstm1,out_dense1])
	out_dense2=dense2(out_merge1)
	output1=dense3(out_dense2)
	model=keras.models.Model(inputs=[input1,input2],outputs=output1)
	model.compile(loss=keras.losses.CategoricalCrossentropy(),optimizer='adam',metrics=['mae','mse','accuracy'])
#	print(model.summary())
#	plot_model(model, to_file='model.png', show_shapes=True)
	return model

# %%
#4. Create complicated sequences:

def create_sequences(tokenizer, max_length, descriptions, photos, vocab_size):
	imgs, txts, outs = list(), list(), list()
	for key,desc_list in descriptions.items():
		for desc in desc_list:
			seq = tokenizer.texts_to_sequences([desc])[0]
			for i in range(1, len(seq)):
				in_seq, out_seq = seq[:i], seq[i]
				in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
				out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
				imgs.append(photos[key])
				txts.append(in_seq)
				outs.append(out_seq)
	return np.array(imgs), np.array(txts), np.array(outs)

# %%
#5. Data-loading function:
def data():
#    image_featurizer()
    image_filenames=req_images()
    map=text_extractor(image_filenames)
    tokenizer=create_tokenizer(map)
    vocab_size=len(tokenizer.word_index)+1
    max_length=max_len(map)
    print('Max_length of a sentence: ',max_length)
    photos=load_photo_features(image_filenames)
    print('Total photo features available: ',len(photos))
    print('Loaded image features and corresponding captions in sequence successfully!')
    return map, tokenizer, vocab_size, max_length, photos
map,tokenizer,vocab_size,max_length,photos=data()
# Out:
# Streaming output truncated to the last 5000 lines.
# Reading captions of  1006 . 2410399168_1462c422d4.jpg ...
# Reading captions of  1007 . 2410399168_1462c422d4.jpg ...
# Reading captions of  1008 . 2410399168_1462c422d4.jpg ...
# Reading captions of  1009 . 2410399168_1462c422d4.jpg ...
# Reading captions of  1010 . 2410399168_1462c422d4.jpg ...
# Reading captions of  1011 . 241346508_0b3907a95b.jpg ...
# Reading captions of  1012 . 241346508_0b3907a95b.jpg ...
# Reading captions of  1013 . 241346508_0b3907a95b.jpg ...
# Reading captions of  1014 . 241346508_0b3907a95b.jpg ...
# Reading captions of  1015 . 241346508_0b3907a95b.jpg ...
# Reading captions of  1016 . 241346580_b3c035d65c.jpg ...
# Reading captions of  1017 . 241346580_b3c035d65c.jpg ...
# Reading captions of  1018 . 241346580_b3c035d65c.jpg ...
# Reading captions of  1019 . 241346580_b3c035d65c.jpg ...
# Reading captions of  1020 . 241346580_b3c035d65c.jpg ...
# Reading captions of  1021 . 241346885_f519ece460.jpg ...
# Reading captions of  1022 . 241346885_f519ece460.jpg ...
# Reading captions of  1023 . 241346885_f519ece460.jpg ...
# Reading captions of  1024 . 241346885_f519ece460.jpg ...
# Reading captions of  1025 . 241346885_f519ece460.jpg ...
# Reading captions of  1026 . 241346923_18bd84bea4.jpg ...
# Reading captions of  1027 . 241346923_18bd84bea4.jpg ...
# Reading captions of  1028 . 241346923_18bd84bea4.jpg ...
# Reading captions of  1029 . 241346923_18bd84bea4.jpg ...
# Reading captions of  1030 . 241346923_18bd84bea4.jpg ...
# Reading captions of  1031 . 241347356_8a515555fd.jpg ...
# Reading captions of  1032 . 241347356_8a515555fd.jpg ...
# Reading captions of  1033 . 241347356_8a515555fd.jpg ...
# Reading captions of  1034 . 241347356_8a515555fd.jpg ...
# Reading captions of  1035 . 241347356_8a515555fd.jpg ...
# Reading captions of  1036 . 241347823_6b25c3e58e.jpg ...
# Reading captions of  1037 . 241347823_6b25c3e58e.jpg ...
# Reading captions of  1038 . 241347823_6b25c3e58e.jpg ...
# Reading captions of  1039 . 241347823_6b25c3e58e.jpg ...
# Reading captions of  1040 . 241347823_6b25c3e58e.jpg ...
# Reading captions of  1041 . 2414397449_2ac3b78e0d.jpg ...
# Reading captions of  1042 . 2414397449_2ac3b78e0d.jpg ...
# Reading captions of  1043 . 2414397449_2ac3b78e0d.jpg ...
# Reading captions of  1044 . 2414397449_2ac3b78e0d.jpg ...
# Reading captions of  1045 . 2414397449_2ac3b78e0d.jpg ...
# Reading captions of  1046 . 2416964653_db3c2b6a0e.jpg ...
# Reading captions of  1047 . 2416964653_db3c2b6a0e.jpg ...
# Reading captions of  1048 . 2416964653_db3c2b6a0e.jpg ...
# Reading captions of  1049 . 2416964653_db3c2b6a0e.jpg ...
# Reading captions of  1050 . 2416964653_db3c2b6a0e.jpg ...
# Reading captions of  1051 . 2418191216_82711d5c5c.jpg ...
# Reading captions of  1052 . 2418191216_82711d5c5c.jpg ...
# Reading captions of  1053 . 2418191216_82711d5c5c.jpg ...
# Reading captions of  1054 . 2418191216_82711d5c5c.jpg ...
# Reading captions of  1055 . 2418191216_82711d5c5c.jpg ...
# Reading captions of  1056 . 2420546021_4a59790da6.jpg ...
# Reading captions of  1057 . 2420546021_4a59790da6.jpg ...
# Reading captions of  1058 . 2420546021_4a59790da6.jpg ...
# Reading captions of  1059 . 2420546021_4a59790da6.jpg ...
# Reading captions of  1060 . 2420546021_4a59790da6.jpg ...
# Reading captions of  1061 . 2425262733_afe0718276.jpg ...
# Reading captions of  1062 . 2425262733_afe0718276.jpg ...
# Reading captions of  1063 . 2425262733_afe0718276.jpg ...
# Reading captions of  1064 . 2425262733_afe0718276.jpg ...
# Reading captions of  1065 . 2425262733_afe0718276.jpg ...
# Reading captions of  1066 . 2428275562_4bde2bc5ea.jpg ...
# Reading captions of  1067 . 2428275562_4bde2bc5ea.jpg ...
# Reading captions of  1068 . 2428275562_4bde2bc5ea.jpg ...
# Reading captions of  1069 . 2428275562_4bde2bc5ea.jpg ...
# Reading captions of  1070 . 2428275562_4bde2bc5ea.jpg ...
# Reading captions of  1071 . 2428959030_bdffc2812e.jpg ...
# Reading captions of  1072 . 2428959030_bdffc2812e.jpg ...
# Reading captions of  1073 . 2428959030_bdffc2812e.jpg ...
# Reading captions of  1074 . 2428959030_bdffc2812e.jpg ...
# Reading captions of  1075 . 2428959030_bdffc2812e.jpg ...
# Reading captions of  1076 . 2429729667_42effc165d.jpg ...
# Reading captions of  1077 . 2429729667_42effc165d.jpg ...
# Reading captions of  1078 . 2429729667_42effc165d.jpg ...
# Reading captions of  1079 . 2429729667_42effc165d.jpg ...
# Reading captions of  1080 . 2429729667_42effc165d.jpg ...
# Reading captions of  1081 . 2429978680_1e18a13835.jpg ...
# Reading captions of  1082 . 2429978680_1e18a13835.jpg ...
# Reading captions of  1083 . 2429978680_1e18a13835.jpg ...
# Reading captions of  1084 . 2429978680_1e18a13835.jpg ...
# Reading captions of  1085 . 2429978680_1e18a13835.jpg ...
# Reading captions of  1086 . 2431120202_b24fe2333a.jpg ...
# Reading captions of  1087 . 2431120202_b24fe2333a.jpg ...
# Reading captions of  1088 . 2431120202_b24fe2333a.jpg ...
# Reading captions of  1089 . 2431120202_b24fe2333a.jpg ...
# Reading captions of  1090 . 2431120202_b24fe2333a.jpg ...
# Reading captions of  1091 . 2432038587_5e4148e277.jpg ...
# Reading captions of  1092 . 2432038587_5e4148e277.jpg ...
# Reading captions of  1093 . 2432038587_5e4148e277.jpg ...
# Reading captions of  1094 . 2432038587_5e4148e277.jpg ...
# Reading captions of  1095 . 2432038587_5e4148e277.jpg ...
# Reading captions of  1096 . 2433175169_da939372f2.jpg ...
# Reading captions of  1097 . 2433175169_da939372f2.jpg ...
# Reading captions of  1098 . 2433175169_da939372f2.jpg ...
# Reading captions of  1099 . 2433175169_da939372f2.jpg ...
# Reading captions of  1100 . 2433175169_da939372f2.jpg ...
# Reading captions of  1101 . 2436081047_bca044c1d3.jpg ...
# Reading captions of  1102 . 2436081047_bca044c1d3.jpg ...
# Reading captions of  1103 . 2436081047_bca044c1d3.jpg ...
# Reading captions of  1104 . 2436081047_bca044c1d3.jpg ...
# Reading captions of  1105 . 2436081047_bca044c1d3.jpg ...
# Reading captions of  1106 . 2436398074_8737f40869.jpg ...
# Reading captions of  1107 . 2436398074_8737f40869.jpg ...
# Reading captions of  1108 . 2436398074_8737f40869.jpg ...
# Reading captions of  1109 . 2436398074_8737f40869.jpg ...
# Reading captions of  1110 . 2436398074_8737f40869.jpg ...
# Reading captions of  1111 . 2443229844_277cded27d.jpg ...
# Reading captions of  1112 . 2443229844_277cded27d.jpg ...
# Reading captions of  1113 . 2443229844_277cded27d.jpg ...
# Reading captions of  1114 . 2443229844_277cded27d.jpg ...
# Reading captions of  1115 . 2443229844_277cded27d.jpg ...
# Reading captions of  1116 . 2449289139_08fc1092c1.jpg ...
# Reading captions of  1117 . 2449289139_08fc1092c1.jpg ...
# Reading captions of  1118 . 2449289139_08fc1092c1.jpg ...
# Reading captions of  1119 . 2449289139_08fc1092c1.jpg ...
# Reading captions of  1120 . 2449289139_08fc1092c1.jpg ...
# Reading captions of  1121 . 2449446913_28fa5b7c75.jpg ...
# Reading captions of  1122 . 2449446913_28fa5b7c75.jpg ...
# Reading captions of  1123 . 2449446913_28fa5b7c75.jpg ...
# Reading captions of  1124 . 2449446913_28fa5b7c75.jpg ...
# Reading captions of  1125 . 2449446913_28fa5b7c75.jpg ...
# Reading captions of  1126 . 2449518585_113dc4a8e5.jpg ...
# Reading captions of  1127 . 2449518585_113dc4a8e5.jpg ...
# Reading captions of  1128 . 2449518585_113dc4a8e5.jpg ...
# Reading captions of  1129 . 2449518585_113dc4a8e5.jpg ...
# Reading captions of  1130 . 2449518585_113dc4a8e5.jpg ...
# Reading captions of  1131 . 2450486758_a66fd296ea.jpg ...
# Reading captions of  1132 . 2450486758_a66fd296ea.jpg ...
# Reading captions of  1133 . 2450486758_a66fd296ea.jpg ...
# Reading captions of  1134 . 2450486758_a66fd296ea.jpg ...
# Reading captions of  1135 . 2450486758_a66fd296ea.jpg ...
# Reading captions of  1136 . 2451988767_244bff98d1.jpg ...
# Reading captions of  1137 . 2451988767_244bff98d1.jpg ...
# Reading captions of  1138 . 2451988767_244bff98d1.jpg ...
# Reading captions of  1139 . 2451988767_244bff98d1.jpg ...
# Reading captions of  1140 . 2451988767_244bff98d1.jpg ...
# Reading captions of  1141 . 2453990033_df53f0d8c8.jpg ...
# Reading captions of  1142 . 2453990033_df53f0d8c8.jpg ...
# Reading captions of  1143 . 2453990033_df53f0d8c8.jpg ...
# Reading captions of  1144 . 2453990033_df53f0d8c8.jpg ...
# Reading captions of  1145 . 2453990033_df53f0d8c8.jpg ...
# Reading captions of  1146 . 2456615908_59cdac6605.jpg ...
# Reading captions of  1147 . 2456615908_59cdac6605.jpg ...
# Reading captions of  1148 . 2456615908_59cdac6605.jpg ...
# Reading captions of  1149 . 2456615908_59cdac6605.jpg ...
# Reading captions of  1150 . 2456615908_59cdac6605.jpg ...
# Reading captions of  1151 . 2458269558_277012780d.jpg ...
# Reading captions of  1152 . 2458269558_277012780d.jpg ...
# Reading captions of  1153 . 2458269558_277012780d.jpg ...
# Reading captions of  1154 . 2458269558_277012780d.jpg ...
# Reading captions of  1155 . 2458269558_277012780d.jpg ...
# Reading captions of  1156 . 2460126267_0deea8b645.jpg ...
# Reading captions of  1157 . 2460126267_0deea8b645.jpg ...
# Reading captions of  1158 . 2460126267_0deea8b645.jpg ...
# Reading captions of  1159 . 2460126267_0deea8b645.jpg ...
# Reading captions of  1160 . 2460126267_0deea8b645.jpg ...
# Reading captions of  1161 . 2460159430_71ab1aacfa.jpg ...
# Reading captions of  1162 . 2460159430_71ab1aacfa.jpg ...
# Reading captions of  1163 . 2460159430_71ab1aacfa.jpg ...
# Reading captions of  1164 . 2460159430_71ab1aacfa.jpg ...
# Reading captions of  1165 . 2460159430_71ab1aacfa.jpg ...
# Reading captions of  1166 . 2461616306_3ee7ac1b4b.jpg ...
# Reading captions of  1167 . 2461616306_3ee7ac1b4b.jpg ...
# Reading captions of  1168 . 2461616306_3ee7ac1b4b.jpg ...
# Reading captions of  1169 . 2461616306_3ee7ac1b4b.jpg ...
# Reading captions of  1170 . 2461616306_3ee7ac1b4b.jpg ...
# Reading captions of  1171 . 2461990494_c5ece064cc.jpg ...
# Reading captions of  1172 . 2461990494_c5ece064cc.jpg ...
# Reading captions of  1173 . 2461990494_c5ece064cc.jpg ...
# Reading captions of  1174 . 2461990494_c5ece064cc.jpg ...
# Reading captions of  1175 . 2461990494_c5ece064cc.jpg ...
# Reading captions of  1176 . 2472980433_210ec62874.jpg ...
# Reading captions of  1177 . 2472980433_210ec62874.jpg ...
# Reading captions of  1178 . 2472980433_210ec62874.jpg ...
# Reading captions of  1179 . 2472980433_210ec62874.jpg ...
# Reading captions of  1180 . 2472980433_210ec62874.jpg ...
# Reading captions of  1181 . 2477623312_58e8e8c8af.jpg ...
# Reading captions of  1182 . 2477623312_58e8e8c8af.jpg ...
# Reading captions of  1183 . 2477623312_58e8e8c8af.jpg ...
# Reading captions of  1184 . 2477623312_58e8e8c8af.jpg ...
# Reading captions of  1185 . 2477623312_58e8e8c8af.jpg ...
# Reading captions of  1186 . 2479652566_8f9fac8af5.jpg ...
# Reading captions of  1187 . 2479652566_8f9fac8af5.jpg ...
# Reading captions of  1188 . 2479652566_8f9fac8af5.jpg ...
# Reading captions of  1189 . 2479652566_8f9fac8af5.jpg ...
# Reading captions of  1190 . 2479652566_8f9fac8af5.jpg ...
# Reading captions of  1191 . 2480832276_fa55480ecb.jpg ...
# Reading captions of  1192 . 2480832276_fa55480ecb.jpg ...
# Reading captions of  1193 . 2480832276_fa55480ecb.jpg ...
# Reading captions of  1194 . 2480832276_fa55480ecb.jpg ...
# Reading captions of  1195 . 2480832276_fa55480ecb.jpg ...
# Reading captions of  1196 . 2485467050_1d5e2696d4.jpg ...
# Reading captions of  1197 . 2485467050_1d5e2696d4.jpg ...
# Reading captions of  1198 . 2485467050_1d5e2696d4.jpg ...
# Reading captions of  1199 . 2485467050_1d5e2696d4.jpg ...
# Reading captions of  1200 . 2485467050_1d5e2696d4.jpg ...
# Reading captions of  1201 . 248858242_1c33c54ada.jpg ...
# Reading captions of  1202 . 248858242_1c33c54ada.jpg ...
# Reading captions of  1203 . 248858242_1c33c54ada.jpg ...
# Reading captions of  1204 . 248858242_1c33c54ada.jpg ...
# Reading captions of  1205 . 248858242_1c33c54ada.jpg ...
# Reading captions of  1206 . 2497608431_8dfefc7a1a.jpg ...
# Reading captions of  1207 . 2497608431_8dfefc7a1a.jpg ...
# Reading captions of  1208 . 2497608431_8dfefc7a1a.jpg ...
# Reading captions of  1209 . 2497608431_8dfefc7a1a.jpg ...
# Reading captions of  1210 . 2497608431_8dfefc7a1a.jpg ...
# Reading captions of  1211 . 2500354186_0836309cc9.jpg ...
# Reading captions of  1212 . 2500354186_0836309cc9.jpg ...
# Reading captions of  1213 . 2500354186_0836309cc9.jpg ...
# Reading captions of  1214 . 2500354186_0836309cc9.jpg ...
# Reading captions of  1215 . 2500354186_0836309cc9.jpg ...
# Reading captions of  1216 . 2501942587_e59b91d1da.jpg ...
# Reading captions of  1217 . 2501942587_e59b91d1da.jpg ...
# Reading captions of  1218 . 2501942587_e59b91d1da.jpg ...
# Reading captions of  1219 . 2501942587_e59b91d1da.jpg ...
# Reading captions of  1220 . 2501942587_e59b91d1da.jpg ...
# Reading captions of  1221 . 2502007071_82a8c639cf.jpg ...
# Reading captions of  1222 . 2502007071_82a8c639cf.jpg ...
# Reading captions of  1223 . 2502007071_82a8c639cf.jpg ...
# Reading captions of  1224 . 2502007071_82a8c639cf.jpg ...
# Reading captions of  1225 . 2502007071_82a8c639cf.jpg ...
# Reading captions of  1226 . 2502079538_10ef2e976b.jpg ...
# Reading captions of  1227 . 2502079538_10ef2e976b.jpg ...
# Reading captions of  1228 . 2502079538_10ef2e976b.jpg ...
# Reading captions of  1229 . 2502079538_10ef2e976b.jpg ...
# Reading captions of  1230 . 2502079538_10ef2e976b.jpg ...
# Reading captions of  1231 . 2502782508_2c8211cd6b.jpg ...
# Reading captions of  1232 . 2502782508_2c8211cd6b.jpg ...
# Reading captions of  1233 . 2502782508_2c8211cd6b.jpg ...
# Reading captions of  1234 . 2502782508_2c8211cd6b.jpg ...
# Reading captions of  1235 . 2502782508_2c8211cd6b.jpg ...
# Reading captions of  1236 . 2505056124_1276e8dbcb.jpg ...
# Reading captions of  1237 . 2505056124_1276e8dbcb.jpg ...
# Reading captions of  1238 . 2505056124_1276e8dbcb.jpg ...
# Reading captions of  1239 . 2505056124_1276e8dbcb.jpg ...
# Reading captions of  1240 . 2505056124_1276e8dbcb.jpg ...
# Reading captions of  1241 . 2505465055_f1e6cf9b76.jpg ...
# Reading captions of  1242 . 2505465055_f1e6cf9b76.jpg ...
# Reading captions of  1243 . 2505465055_f1e6cf9b76.jpg ...
# Reading captions of  1244 . 2505465055_f1e6cf9b76.jpg ...
# Reading captions of  1245 . 2505465055_f1e6cf9b76.jpg ...
# Reading captions of  1246 . 2518094853_dfce24ce8c.jpg ...
# Reading captions of  1247 . 2518094853_dfce24ce8c.jpg ...
# Reading captions of  1248 . 2518094853_dfce24ce8c.jpg ...
# Reading captions of  1249 . 2518094853_dfce24ce8c.jpg ...
# Reading captions of  1250 . 2518094853_dfce24ce8c.jpg ...
# Reading captions of  1251 . 2519483556_2b1632a18c.jpg ...
# Reading captions of  1252 . 2519483556_2b1632a18c.jpg ...
# Reading captions of  1253 . 2519483556_2b1632a18c.jpg ...
# Reading captions of  1254 . 2519483556_2b1632a18c.jpg ...
# Reading captions of  1255 . 2519483556_2b1632a18c.jpg ...
# Reading captions of  1256 . 2521878609_146143708e.jpg ...
# Reading captions of  1257 . 2521878609_146143708e.jpg ...
# Reading captions of  1258 . 2521878609_146143708e.jpg ...
# Reading captions of  1259 . 2521878609_146143708e.jpg ...
# Reading captions of  1260 . 2521878609_146143708e.jpg ...
# Reading captions of  1261 . 2529116152_4331dabf50.jpg ...
# Reading captions of  1262 . 2529116152_4331dabf50.jpg ...
# Reading captions of  1263 . 2529116152_4331dabf50.jpg ...
# Reading captions of  1264 . 2529116152_4331dabf50.jpg ...
# Reading captions of  1265 . 2529116152_4331dabf50.jpg ...
# Reading captions of  1266 . 2533424347_cf2f84872b.jpg ...
# Reading captions of  1267 . 2533424347_cf2f84872b.jpg ...
# Reading captions of  1268 . 2533424347_cf2f84872b.jpg ...
# Reading captions of  1269 . 2533424347_cf2f84872b.jpg ...
# Reading captions of  1270 . 2533424347_cf2f84872b.jpg ...
# Reading captions of  1271 . 2535746605_8124bf4e4f.jpg ...
# Reading captions of  1272 . 2535746605_8124bf4e4f.jpg ...
# Reading captions of  1273 . 2535746605_8124bf4e4f.jpg ...
# Reading captions of  1274 . 2535746605_8124bf4e4f.jpg ...
# Reading captions of  1275 . 2535746605_8124bf4e4f.jpg ...
# Reading captions of  1276 . 2540326842_bb26cec999.jpg ...
# Reading captions of  1277 . 2540326842_bb26cec999.jpg ...
# Reading captions of  1278 . 2540326842_bb26cec999.jpg ...
# Reading captions of  1279 . 2540326842_bb26cec999.jpg ...
# Reading captions of  1280 . 2540326842_bb26cec999.jpg ...
# Reading captions of  1281 . 254527963_3f5824b0e8.jpg ...
# Reading captions of  1282 . 254527963_3f5824b0e8.jpg ...
# Reading captions of  1283 . 254527963_3f5824b0e8.jpg ...
# Reading captions of  1284 . 254527963_3f5824b0e8.jpg ...
# Reading captions of  1285 . 254527963_3f5824b0e8.jpg ...
# Reading captions of  1286 . 2546959333_23b957988f.jpg ...
# Reading captions of  1287 . 2546959333_23b957988f.jpg ...
# Reading captions of  1288 . 2546959333_23b957988f.jpg ...
# Reading captions of  1289 . 2546959333_23b957988f.jpg ...
# Reading captions of  1290 . 2546959333_23b957988f.jpg ...
# Reading captions of  1291 . 2555535057_007501dae5.jpg ...
# Reading captions of  1292 . 2555535057_007501dae5.jpg ...
# Reading captions of  1293 . 2555535057_007501dae5.jpg ...
# Reading captions of  1294 . 2555535057_007501dae5.jpg ...
# Reading captions of  1295 . 2555535057_007501dae5.jpg ...
# Reading captions of  1296 . 255741044_1102982213.jpg ...
# Reading captions of  1297 . 255741044_1102982213.jpg ...
# Reading captions of  1298 . 255741044_1102982213.jpg ...
# Reading captions of  1299 . 255741044_1102982213.jpg ...
# Reading captions of  1300 . 255741044_1102982213.jpg ...
# Reading captions of  1301 . 2557922709_24d2a9655a.jpg ...
# Reading captions of  1302 . 2557922709_24d2a9655a.jpg ...
# Reading captions of  1303 . 2557922709_24d2a9655a.jpg ...
# Reading captions of  1304 . 2557922709_24d2a9655a.jpg ...
# Reading captions of  1305 . 2557922709_24d2a9655a.jpg ...
# Reading captions of  1306 . 2557972410_6925fe695c.jpg ...
# Reading captions of  1307 . 2557972410_6925fe695c.jpg ...
# Reading captions of  1308 . 2557972410_6925fe695c.jpg ...
# Reading captions of  1309 . 2557972410_6925fe695c.jpg ...
# Reading captions of  1310 . 2557972410_6925fe695c.jpg ...
# Reading captions of  1311 . 2558911884_856dfc3951.jpg ...
# Reading captions of  1312 . 2558911884_856dfc3951.jpg ...
# Reading captions of  1313 . 2558911884_856dfc3951.jpg ...
# Reading captions of  1314 . 2558911884_856dfc3951.jpg ...
# Reading captions of  1315 . 2558911884_856dfc3951.jpg ...
# Reading captions of  1316 . 2560388887_55abc9083d.jpg ...
# Reading captions of  1317 . 2560388887_55abc9083d.jpg ...
# Reading captions of  1318 . 2560388887_55abc9083d.jpg ...
# Reading captions of  1319 . 2560388887_55abc9083d.jpg ...
# Reading captions of  1320 . 2560388887_55abc9083d.jpg ...
# Reading captions of  1321 . 2561481438_447b852e4d.jpg ...
# Reading captions of  1322 . 2561481438_447b852e4d.jpg ...
# Reading captions of  1323 . 2561481438_447b852e4d.jpg ...
# Reading captions of  1324 . 2561481438_447b852e4d.jpg ...
# Reading captions of  1325 . 2561481438_447b852e4d.jpg ...
# Reading captions of  1326 . 2562377955_8d670ccec6.jpg ...
# Reading captions of  1327 . 2562377955_8d670ccec6.jpg ...
# Reading captions of  1328 . 2562377955_8d670ccec6.jpg ...
# Reading captions of  1329 . 2562377955_8d670ccec6.jpg ...
# Reading captions of  1330 . 2562377955_8d670ccec6.jpg ...
# Reading captions of  1331 . 256439287_990ac4a761.jpg ...
# Reading captions of  1332 . 256439287_990ac4a761.jpg ...
# Reading captions of  1333 . 256439287_990ac4a761.jpg ...
# Reading captions of  1334 . 256439287_990ac4a761.jpg ...
# Reading captions of  1335 . 256439287_990ac4a761.jpg ...
# Reading captions of  1336 . 2564663851_3a9832e4fc.jpg ...
# Reading captions of  1337 . 2564663851_3a9832e4fc.jpg ...
# Reading captions of  1338 . 2564663851_3a9832e4fc.jpg ...
# Reading captions of  1339 . 2564663851_3a9832e4fc.jpg ...
# Reading captions of  1340 . 2564663851_3a9832e4fc.jpg ...
# Reading captions of  1341 . 2564888404_b57f89d3c7.jpg ...
# Reading captions of  1342 . 2564888404_b57f89d3c7.jpg ...
# Reading captions of  1343 . 2564888404_b57f89d3c7.jpg ...
# Reading captions of  1344 . 2564888404_b57f89d3c7.jpg ...
# Reading captions of  1345 . 2564888404_b57f89d3c7.jpg ...
# Reading captions of  1346 . 256958382_b9006bfc5b.jpg ...
# Reading captions of  1347 . 256958382_b9006bfc5b.jpg ...
# Reading captions of  1348 . 256958382_b9006bfc5b.jpg ...
# Reading captions of  1349 . 256958382_b9006bfc5b.jpg ...
# Reading captions of  1350 . 256958382_b9006bfc5b.jpg ...
# Reading captions of  1351 . 2572101672_4d699c8713.jpg ...
# Reading captions of  1352 . 2572101672_4d699c8713.jpg ...
# Reading captions of  1353 . 2572101672_4d699c8713.jpg ...
# Reading captions of  1354 . 2572101672_4d699c8713.jpg ...
# Reading captions of  1355 . 2572101672_4d699c8713.jpg ...
# Reading captions of  1356 . 2574230252_f5a1382dd4.jpg ...
# Reading captions of  1357 . 2574230252_f5a1382dd4.jpg ...
# Reading captions of  1358 . 2574230252_f5a1382dd4.jpg ...
# Reading captions of  1359 . 2574230252_f5a1382dd4.jpg ...
# Reading captions of  1360 . 2574230252_f5a1382dd4.jpg ...
# Reading captions of  1361 . 2574509968_e4692ae169.jpg ...
# Reading captions of  1362 . 2574509968_e4692ae169.jpg ...
# Reading captions of  1363 . 2574509968_e4692ae169.jpg ...
# Reading captions of  1364 . 2574509968_e4692ae169.jpg ...
# Reading captions of  1365 . 2574509968_e4692ae169.jpg ...
# Reading captions of  1366 . 2579460386_94c489028d.jpg ...
# Reading captions of  1367 . 2579460386_94c489028d.jpg ...
# Reading captions of  1368 . 2579460386_94c489028d.jpg ...
# Reading captions of  1369 . 2579460386_94c489028d.jpg ...
# Reading captions of  1370 . 2579460386_94c489028d.jpg ...
# Reading captions of  1371 . 2582390123_71120edb0c.jpg ...
# Reading captions of  1372 . 2582390123_71120edb0c.jpg ...
# Reading captions of  1373 . 2582390123_71120edb0c.jpg ...
# Reading captions of  1374 . 2582390123_71120edb0c.jpg ...
# Reading captions of  1375 . 2582390123_71120edb0c.jpg ...
# Reading captions of  1376 . 2584957647_4f9235c150.jpg ...
# Reading captions of  1377 . 2584957647_4f9235c150.jpg ...
# Reading captions of  1378 . 2584957647_4f9235c150.jpg ...
# Reading captions of  1379 . 2584957647_4f9235c150.jpg ...
# Reading captions of  1380 . 2584957647_4f9235c150.jpg ...
# Reading captions of  1381 . 2588927489_f4da2f11ec.jpg ...
# Reading captions of  1382 . 2588927489_f4da2f11ec.jpg ...
# Reading captions of  1383 . 2588927489_f4da2f11ec.jpg ...
# Reading captions of  1384 . 2588927489_f4da2f11ec.jpg ...
# Reading captions of  1385 . 2588927489_f4da2f11ec.jpg ...
# Reading captions of  1386 . 2589156742_c46bc82137.jpg ...
# Reading captions of  1387 . 2589156742_c46bc82137.jpg ...
# Reading captions of  1388 . 2589156742_c46bc82137.jpg ...
# Reading captions of  1389 . 2589156742_c46bc82137.jpg ...
# Reading captions of  1390 . 2589156742_c46bc82137.jpg ...
# Reading captions of  1391 . 2592019072_a6c0090da4.jpg ...
# Reading captions of  1392 . 2592019072_a6c0090da4.jpg ...
# Reading captions of  1393 . 2592019072_a6c0090da4.jpg ...
# Reading captions of  1394 . 2592019072_a6c0090da4.jpg ...
# Reading captions of  1395 . 2592019072_a6c0090da4.jpg ...
# Reading captions of  1396 . 259314892_a42b8af664.jpg ...
# Reading captions of  1397 . 259314892_a42b8af664.jpg ...
# Reading captions of  1398 . 259314892_a42b8af664.jpg ...
# Reading captions of  1399 . 259314892_a42b8af664.jpg ...
# Reading captions of  1400 . 259314892_a42b8af664.jpg ...
# Reading captions of  1401 . 2595102568_347f6d4b07.jpg ...
# Reading captions of  1402 . 2595102568_347f6d4b07.jpg ...
# Reading captions of  1403 . 2595102568_347f6d4b07.jpg ...
# Reading captions of  1404 . 2595102568_347f6d4b07.jpg ...
# Reading captions of  1405 . 2595102568_347f6d4b07.jpg ...
# Reading captions of  1406 . 2596474836_79468f23a0.jpg ...
# Reading captions of  1407 . 2596474836_79468f23a0.jpg ...
# Reading captions of  1408 . 2596474836_79468f23a0.jpg ...
# Reading captions of  1409 . 2596474836_79468f23a0.jpg ...
# Reading captions of  1410 . 2596474836_79468f23a0.jpg ...
# Reading captions of  1411 . 2597958208_e03aa149c9.jpg ...
# Reading captions of  1412 . 2597958208_e03aa149c9.jpg ...
# Reading captions of  1413 . 2597958208_e03aa149c9.jpg ...
# Reading captions of  1414 . 2597958208_e03aa149c9.jpg ...
# Reading captions of  1415 . 2597958208_e03aa149c9.jpg ...
# Reading captions of  1416 . 2598012140_832863fcb9.jpg ...
# Reading captions of  1417 . 2598012140_832863fcb9.jpg ...
# Reading captions of  1418 . 2598012140_832863fcb9.jpg ...
# Reading captions of  1419 . 2598012140_832863fcb9.jpg ...
# Reading captions of  1420 . 2598012140_832863fcb9.jpg ...
# Reading captions of  1421 . 2601008162_f00eeb5c14.jpg ...
# Reading captions of  1422 . 2601008162_f00eeb5c14.jpg ...
# Reading captions of  1423 . 2601008162_f00eeb5c14.jpg ...
# Reading captions of  1424 . 2601008162_f00eeb5c14.jpg ...
# Reading captions of  1425 . 2601008162_f00eeb5c14.jpg ...
# Reading captions of  1426 . 2602279427_191773c9e2.jpg ...
# Reading captions of  1427 . 2602279427_191773c9e2.jpg ...
# Reading captions of  1428 . 2602279427_191773c9e2.jpg ...
# Reading captions of  1429 . 2602279427_191773c9e2.jpg ...
# Reading captions of  1430 . 2602279427_191773c9e2.jpg ...
# Reading captions of  1431 . 2603125422_659391f961.jpg ...
# Reading captions of  1432 . 2603125422_659391f961.jpg ...
# Reading captions of  1433 . 2603125422_659391f961.jpg ...
# Reading captions of  1434 . 2603125422_659391f961.jpg ...
# Reading captions of  1435 . 2603125422_659391f961.jpg ...
# Reading captions of  1436 . 2603792708_18a97bac97.jpg ...
# Reading captions of  1437 . 2603792708_18a97bac97.jpg ...
# Reading captions of  1438 . 2603792708_18a97bac97.jpg ...
# Reading captions of  1439 . 2603792708_18a97bac97.jpg ...
# Reading captions of  1440 . 2603792708_18a97bac97.jpg ...
# Reading captions of  1441 . 260850192_fd03ea26f1.jpg ...
# Reading captions of  1442 . 260850192_fd03ea26f1.jpg ...
# Reading captions of  1443 . 260850192_fd03ea26f1.jpg ...
# Reading captions of  1444 . 260850192_fd03ea26f1.jpg ...
# Reading captions of  1445 . 260850192_fd03ea26f1.jpg ...
# Reading captions of  1446 . 262439544_e71cd26b24.jpg ...
# Reading captions of  1447 . 262439544_e71cd26b24.jpg ...
# Reading captions of  1448 . 262439544_e71cd26b24.jpg ...
# Reading captions of  1449 . 262439544_e71cd26b24.jpg ...
# Reading captions of  1450 . 262439544_e71cd26b24.jpg ...
# Reading captions of  1451 . 2629445284_83390e83af.jpg ...
# Reading captions of  1452 . 2629445284_83390e83af.jpg ...
# Reading captions of  1453 . 2629445284_83390e83af.jpg ...
# Reading captions of  1454 . 2629445284_83390e83af.jpg ...
# Reading captions of  1455 . 2629445284_83390e83af.jpg ...
# Reading captions of  1456 . 2632366677_43dee456a5.jpg ...
# Reading captions of  1457 . 2632366677_43dee456a5.jpg ...
# Reading captions of  1458 . 2632366677_43dee456a5.jpg ...
# Reading captions of  1459 . 2632366677_43dee456a5.jpg ...
# Reading captions of  1460 . 2632366677_43dee456a5.jpg ...
# Reading captions of  1461 . 2636876892_9353521a1c.jpg ...
# Reading captions of  1462 . 2636876892_9353521a1c.jpg ...
# Reading captions of  1463 . 2636876892_9353521a1c.jpg ...
# Reading captions of  1464 . 2636876892_9353521a1c.jpg ...
# Reading captions of  1465 . 2636876892_9353521a1c.jpg ...
# Reading captions of  1466 . 2640000969_b5404a5143.jpg ...
# Reading captions of  1467 . 2640000969_b5404a5143.jpg ...
# Reading captions of  1468 . 2640000969_b5404a5143.jpg ...
# Reading captions of  1469 . 2640000969_b5404a5143.jpg ...
# Reading captions of  1470 . 2640000969_b5404a5143.jpg ...
# Reading captions of  1471 . 2641288004_30ce961211.jpg ...
# Reading captions of  1472 . 2641288004_30ce961211.jpg ...
# Reading captions of  1473 . 2641288004_30ce961211.jpg ...
# Reading captions of  1474 . 2641288004_30ce961211.jpg ...
# Reading captions of  1475 . 2641288004_30ce961211.jpg ...
# Reading captions of  1476 . 2642350864_099c0f2152.jpg ...
# Reading captions of  1477 . 2642350864_099c0f2152.jpg ...
# Reading captions of  1478 . 2642350864_099c0f2152.jpg ...
# Reading captions of  1479 . 2642350864_099c0f2152.jpg ...
# Reading captions of  1480 . 2642350864_099c0f2152.jpg ...
# Reading captions of  1481 . 264859622_f3a00ab409.jpg ...
# Reading captions of  1482 . 264859622_f3a00ab409.jpg ...
# Reading captions of  1483 . 264859622_f3a00ab409.jpg ...
# Reading captions of  1484 . 264859622_f3a00ab409.jpg ...
# Reading captions of  1485 . 264859622_f3a00ab409.jpg ...
# Reading captions of  1486 . 2650620212_0586016e0d.jpg ...
# Reading captions of  1487 . 2650620212_0586016e0d.jpg ...
# Reading captions of  1488 . 2650620212_0586016e0d.jpg ...
# Reading captions of  1489 . 2650620212_0586016e0d.jpg ...
# Reading captions of  1490 . 2650620212_0586016e0d.jpg ...
# Reading captions of  1491 . 2655183854_5852790214.jpg ...
# Reading captions of  1492 . 2655183854_5852790214.jpg ...
# Reading captions of  1493 . 2655183854_5852790214.jpg ...
# Reading captions of  1494 . 2655183854_5852790214.jpg ...
# Reading captions of  1495 . 2655183854_5852790214.jpg ...
# Reading captions of  1496 . 2656039837_f46b29af92.jpg ...
# Reading captions of  1497 . 2656039837_f46b29af92.jpg ...
# Reading captions of  1498 . 2656039837_f46b29af92.jpg ...
# Reading captions of  1499 . 2656039837_f46b29af92.jpg ...
# Reading captions of  1500 . 2656039837_f46b29af92.jpg ...
# Reading captions of  1501 . 2659554389_ed3d15093f.jpg ...
# Reading captions of  1502 . 2659554389_ed3d15093f.jpg ...
# Reading captions of  1503 . 2659554389_ed3d15093f.jpg ...
# Reading captions of  1504 . 2659554389_ed3d15093f.jpg ...
# Reading captions of  1505 . 2659554389_ed3d15093f.jpg ...
# Reading captions of  1506 . 2661294969_1388b4738c.jpg ...
# Reading captions of  1507 . 2661294969_1388b4738c.jpg ...
# Reading captions of  1508 . 2661294969_1388b4738c.jpg ...
# Reading captions of  1509 . 2661294969_1388b4738c.jpg ...
# Reading captions of  1510 . 2661294969_1388b4738c.jpg ...
# Reading captions of  1511 . 2662816021_ac474e0fde.jpg ...
# Reading captions of  1512 . 2662816021_ac474e0fde.jpg ...
# Reading captions of  1513 . 2662816021_ac474e0fde.jpg ...
# Reading captions of  1514 . 2662816021_ac474e0fde.jpg ...
# Reading captions of  1515 . 2662816021_ac474e0fde.jpg ...
# Reading captions of  1516 . 2664103423_c539f61016.jpg ...
# Reading captions of  1517 . 2664103423_c539f61016.jpg ...
# Reading captions of  1518 . 2664103423_c539f61016.jpg ...
# Reading captions of  1519 . 2664103423_c539f61016.jpg ...
# Reading captions of  1520 . 2664103423_c539f61016.jpg ...
# Reading captions of  1521 . 2667549961_57e5e2c0a5.jpg ...
# Reading captions of  1522 . 2667549961_57e5e2c0a5.jpg ...
# Reading captions of  1523 . 2667549961_57e5e2c0a5.jpg ...
# Reading captions of  1524 . 2667549961_57e5e2c0a5.jpg ...
# Reading captions of  1525 . 2667549961_57e5e2c0a5.jpg ...
# Reading captions of  1526 . 267015208_d80b3eb94d.jpg ...
# Reading captions of  1527 . 267015208_d80b3eb94d.jpg ...
# Reading captions of  1528 . 267015208_d80b3eb94d.jpg ...
# Reading captions of  1529 . 267015208_d80b3eb94d.jpg ...
# Reading captions of  1530 . 267015208_d80b3eb94d.jpg ...
# Reading captions of  1531 . 2670560883_7e7b563092.jpg ...
# Reading captions of  1532 . 2670560883_7e7b563092.jpg ...
# Reading captions of  1533 . 2670560883_7e7b563092.jpg ...
# Reading captions of  1534 . 2670560883_7e7b563092.jpg ...
# Reading captions of  1535 . 2670560883_7e7b563092.jpg ...
# Reading captions of  1536 . 2673148534_8daf0de833.jpg ...
# Reading captions of  1537 . 2673148534_8daf0de833.jpg ...
# Reading captions of  1538 . 2673148534_8daf0de833.jpg ...
# Reading captions of  1539 . 2673148534_8daf0de833.jpg ...
# Reading captions of  1540 . 2673148534_8daf0de833.jpg ...
# Reading captions of  1541 . 2676015068_690b0fb2cd.jpg ...
# Reading captions of  1542 . 2676015068_690b0fb2cd.jpg ...
# Reading captions of  1543 . 2676015068_690b0fb2cd.jpg ...
# Reading captions of  1544 . 2676015068_690b0fb2cd.jpg ...
# Reading captions of  1545 . 2676015068_690b0fb2cd.jpg ...
# Reading captions of  1546 . 2679565682_91ecd283ff.jpg ...
# Reading captions of  1547 . 2679565682_91ecd283ff.jpg ...
# Reading captions of  1548 . 2679565682_91ecd283ff.jpg ...
# Reading captions of  1549 . 2679565682_91ecd283ff.jpg ...
# Reading captions of  1550 . 2679565682_91ecd283ff.jpg ...
# Reading captions of  1551 . 2683985894_167d267dcb.jpg ...
# Reading captions of  1552 . 2683985894_167d267dcb.jpg ...
# Reading captions of  1553 . 2683985894_167d267dcb.jpg ...
# Reading captions of  1554 . 2683985894_167d267dcb.jpg ...
# Reading captions of  1555 . 2683985894_167d267dcb.jpg ...
# Reading captions of  1556 . 2684322797_85406f571d.jpg ...
# Reading captions of  1557 . 2684322797_85406f571d.jpg ...
# Reading captions of  1558 . 2684322797_85406f571d.jpg ...
# Reading captions of  1559 . 2684322797_85406f571d.jpg ...
# Reading captions of  1560 . 2684322797_85406f571d.jpg ...
# Reading captions of  1561 . 2685139184_4ff45e0f76.jpg ...
# Reading captions of  1562 . 2685139184_4ff45e0f76.jpg ...
# Reading captions of  1563 . 2685139184_4ff45e0f76.jpg ...
# Reading captions of  1564 . 2685139184_4ff45e0f76.jpg ...
# Reading captions of  1565 . 2685139184_4ff45e0f76.jpg ...
# Reading captions of  1566 . 2685752892_9d5cd7f274.jpg ...
# Reading captions of  1567 . 2685752892_9d5cd7f274.jpg ...
# Reading captions of  1568 . 2685752892_9d5cd7f274.jpg ...
# Reading captions of  1569 . 2685752892_9d5cd7f274.jpg ...
# Reading captions of  1570 . 2685752892_9d5cd7f274.jpg ...
# Reading captions of  1571 . 2696866120_254a0345bc.jpg ...
# Reading captions of  1572 . 2696866120_254a0345bc.jpg ...
# Reading captions of  1573 . 2696866120_254a0345bc.jpg ...
# Reading captions of  1574 . 2696866120_254a0345bc.jpg ...
# Reading captions of  1575 . 2696866120_254a0345bc.jpg ...
# Reading captions of  1576 . 270263570_3160f360d3.jpg ...
# Reading captions of  1577 . 270263570_3160f360d3.jpg ...
# Reading captions of  1578 . 270263570_3160f360d3.jpg ...
# Reading captions of  1579 . 270263570_3160f360d3.jpg ...
# Reading captions of  1580 . 270263570_3160f360d3.jpg ...
# Reading captions of  1581 . 2704379125_9c35650d16.jpg ...
# Reading captions of  1582 . 2704379125_9c35650d16.jpg ...
# Reading captions of  1583 . 2704379125_9c35650d16.jpg ...
# Reading captions of  1584 . 2704379125_9c35650d16.jpg ...
# Reading captions of  1585 . 2704379125_9c35650d16.jpg ...
# Reading captions of  1586 . 2712352554_1cafd32812.jpg ...
# Reading captions of  1587 . 2712352554_1cafd32812.jpg ...
# Reading captions of  1588 . 2712352554_1cafd32812.jpg ...
# Reading captions of  1589 . 2712352554_1cafd32812.jpg ...
# Reading captions of  1590 . 2712352554_1cafd32812.jpg ...
# Reading captions of  1591 . 2712787899_d85048eb6a.jpg ...
# Reading captions of  1592 . 2712787899_d85048eb6a.jpg ...
# Reading captions of  1593 . 2712787899_d85048eb6a.jpg ...
# Reading captions of  1594 . 2712787899_d85048eb6a.jpg ...
# Reading captions of  1595 . 2712787899_d85048eb6a.jpg ...
# Reading captions of  1596 . 2712974062_6d5b6aa7f0.jpg ...
# Reading captions of  1597 . 2712974062_6d5b6aa7f0.jpg ...
# Reading captions of  1598 . 2712974062_6d5b6aa7f0.jpg ...
# Reading captions of  1599 . 2712974062_6d5b6aa7f0.jpg ...
# Reading captions of  1600 . 2712974062_6d5b6aa7f0.jpg ...
# Reading captions of  1601 . 2714878018_1593c38d69.jpg ...
# Reading captions of  1602 . 2714878018_1593c38d69.jpg ...
# Reading captions of  1603 . 2714878018_1593c38d69.jpg ...
# Reading captions of  1604 . 2714878018_1593c38d69.jpg ...
# Reading captions of  1605 . 2714878018_1593c38d69.jpg ...
# Reading captions of  1606 . 2720215226_5a98ff2bd3.jpg ...
# Reading captions of  1607 . 2720215226_5a98ff2bd3.jpg ...
# Reading captions of  1608 . 2720215226_5a98ff2bd3.jpg ...
# Reading captions of  1609 . 2720215226_5a98ff2bd3.jpg ...
# Reading captions of  1610 . 2720215226_5a98ff2bd3.jpg ...
# Reading captions of  1611 . 2735792721_b8fe85e803.jpg ...
# Reading captions of  1612 . 2735792721_b8fe85e803.jpg ...
# Reading captions of  1613 . 2735792721_b8fe85e803.jpg ...
# Reading captions of  1614 . 2735792721_b8fe85e803.jpg ...
# Reading captions of  1615 . 2735792721_b8fe85e803.jpg ...
# Reading captions of  1616 . 2737609659_efce872c24.jpg ...
# Reading captions of  1617 . 2737609659_efce872c24.jpg ...
# Reading captions of  1618 . 2737609659_efce872c24.jpg ...
# Reading captions of  1619 . 2737609659_efce872c24.jpg ...
# Reading captions of  1620 . 2737609659_efce872c24.jpg ...
# Reading captions of  1621 . 2742426734_291df6da08.jpg ...
# Reading captions of  1622 . 2742426734_291df6da08.jpg ...
# Reading captions of  1623 . 2742426734_291df6da08.jpg ...
# Reading captions of  1624 . 2742426734_291df6da08.jpg ...
# Reading captions of  1625 . 2742426734_291df6da08.jpg ...
# Reading captions of  1626 . 2743709828_a795a75bfc.jpg ...
# Reading captions of  1627 . 2743709828_a795a75bfc.jpg ...
# Reading captions of  1628 . 2743709828_a795a75bfc.jpg ...
# Reading captions of  1629 . 2743709828_a795a75bfc.jpg ...
# Reading captions of  1630 . 2743709828_a795a75bfc.jpg ...
# Reading captions of  1631 . 2747640247_b54bfa6886.jpg ...
# Reading captions of  1632 . 2747640247_b54bfa6886.jpg ...
# Reading captions of  1633 . 2747640247_b54bfa6886.jpg ...
# Reading captions of  1634 . 2747640247_b54bfa6886.jpg ...
# Reading captions of  1635 . 2747640247_b54bfa6886.jpg ...
# Reading captions of  1636 . 2750867389_4b815f793a.jpg ...
# Reading captions of  1637 . 2750867389_4b815f793a.jpg ...
# Reading captions of  1638 . 2750867389_4b815f793a.jpg ...
# Reading captions of  1639 . 2750867389_4b815f793a.jpg ...
# Reading captions of  1640 . 2750867389_4b815f793a.jpg ...
# Reading captions of  1641 . 2751567262_e089b33ed9.jpg ...
# Reading captions of  1642 . 2751567262_e089b33ed9.jpg ...
# Reading captions of  1643 . 2751567262_e089b33ed9.jpg ...
# Reading captions of  1644 . 2751567262_e089b33ed9.jpg ...
# Reading captions of  1645 . 2751567262_e089b33ed9.jpg ...
# Reading captions of  1646 . 2755053974_5cc157512e.jpg ...
# Reading captions of  1647 . 2755053974_5cc157512e.jpg ...
# Reading captions of  1648 . 2755053974_5cc157512e.jpg ...
# Reading captions of  1649 . 2755053974_5cc157512e.jpg ...
# Reading captions of  1650 . 2755053974_5cc157512e.jpg ...
# Reading captions of  1651 . 2755362721_368cbde668.jpg ...
# Reading captions of  1652 . 2755362721_368cbde668.jpg ...
# Reading captions of  1653 . 2755362721_368cbde668.jpg ...
# Reading captions of  1654 . 2755362721_368cbde668.jpg ...
# Reading captions of  1655 . 2755362721_368cbde668.jpg ...
# Reading captions of  1656 . 2757803246_8aa3499d26.jpg ...
# Reading captions of  1657 . 2757803246_8aa3499d26.jpg ...
# Reading captions of  1658 . 2757803246_8aa3499d26.jpg ...
# Reading captions of  1659 . 2757803246_8aa3499d26.jpg ...
# Reading captions of  1660 . 2757803246_8aa3499d26.jpg ...
# Reading captions of  1661 . 2759596272_e0ce0a965a.jpg ...
# Reading captions of  1662 . 2759596272_e0ce0a965a.jpg ...
# Reading captions of  1663 . 2759596272_e0ce0a965a.jpg ...
# Reading captions of  1664 . 2759596272_e0ce0a965a.jpg ...
# Reading captions of  1665 . 2759596272_e0ce0a965a.jpg ...
# Reading captions of  1666 . 2759860913_f75b39d783.jpg ...
# Reading captions of  1667 . 2759860913_f75b39d783.jpg ...
# Reading captions of  1668 . 2759860913_f75b39d783.jpg ...
# Reading captions of  1669 . 2759860913_f75b39d783.jpg ...
# Reading captions of  1670 . 2759860913_f75b39d783.jpg ...
# Reading captions of  1671 . 2762301555_48a0d0aa24.jpg ...
# Reading captions of  1672 . 2762301555_48a0d0aa24.jpg ...
# Reading captions of  1673 . 2762301555_48a0d0aa24.jpg ...
# Reading captions of  1674 . 2762301555_48a0d0aa24.jpg ...
# Reading captions of  1675 . 2762301555_48a0d0aa24.jpg ...
# Reading captions of  1676 . 276356412_dfa01c3c9e.jpg ...
# Reading captions of  1677 . 276356412_dfa01c3c9e.jpg ...
# Reading captions of  1678 . 276356412_dfa01c3c9e.jpg ...
# Reading captions of  1679 . 276356412_dfa01c3c9e.jpg ...
# Reading captions of  1680 . 276356412_dfa01c3c9e.jpg ...
# Reading captions of  1681 . 2763601657_09a52a063f.jpg ...
# Reading captions of  1682 . 2763601657_09a52a063f.jpg ...
# Reading captions of  1683 . 2763601657_09a52a063f.jpg ...
# Reading captions of  1684 . 2763601657_09a52a063f.jpg ...
# Reading captions of  1685 . 2763601657_09a52a063f.jpg ...
# Reading captions of  1686 . 2764178773_d63b502812.jpg ...
# Reading captions of  1687 . 2764178773_d63b502812.jpg ...
# Reading captions of  1688 . 2764178773_d63b502812.jpg ...
# Reading captions of  1689 . 2764178773_d63b502812.jpg ...
# Reading captions of  1690 . 2764178773_d63b502812.jpg ...
# Reading captions of  1691 . 2769731772_18c44c18e2.jpg ...
# Reading captions of  1692 . 2769731772_18c44c18e2.jpg ...
# Reading captions of  1693 . 2769731772_18c44c18e2.jpg ...
# Reading captions of  1694 . 2769731772_18c44c18e2.jpg ...
# Reading captions of  1695 . 2769731772_18c44c18e2.jpg ...
# Reading captions of  1696 . 2774581025_81a3074e2e.jpg ...
# Reading captions of  1697 . 2774581025_81a3074e2e.jpg ...
# Reading captions of  1698 . 2774581025_81a3074e2e.jpg ...
# Reading captions of  1699 . 2774581025_81a3074e2e.jpg ...
# Reading captions of  1700 . 2774581025_81a3074e2e.jpg ...
# Reading captions of  1701 . 278002800_3817135105.jpg ...
# Reading captions of  1702 . 278002800_3817135105.jpg ...
# Reading captions of  1703 . 278002800_3817135105.jpg ...
# Reading captions of  1704 . 278002800_3817135105.jpg ...
# Reading captions of  1705 . 278002800_3817135105.jpg ...
# Reading captions of  1706 . 2782433864_5a0c311d87.jpg ...
# Reading captions of  1707 . 2782433864_5a0c311d87.jpg ...
# Reading captions of  1708 . 2782433864_5a0c311d87.jpg ...
# Reading captions of  1709 . 2782433864_5a0c311d87.jpg ...
# Reading captions of  1710 . 2782433864_5a0c311d87.jpg ...
# Reading captions of  1711 . 2784625888_71a421e171.jpg ...
# Reading captions of  1712 . 2784625888_71a421e171.jpg ...
# Reading captions of  1713 . 2784625888_71a421e171.jpg ...
# Reading captions of  1714 . 2784625888_71a421e171.jpg ...
# Reading captions of  1715 . 2784625888_71a421e171.jpg ...
# Reading captions of  1716 . 2785108434_cd4a1c949c.jpg ...
# Reading captions of  1717 . 2785108434_cd4a1c949c.jpg ...
# Reading captions of  1718 . 2785108434_cd4a1c949c.jpg ...
# Reading captions of  1719 . 2785108434_cd4a1c949c.jpg ...
# Reading captions of  1720 . 2785108434_cd4a1c949c.jpg ...
# Reading captions of  1721 . 2787276494_82703f570a.jpg ...
# Reading captions of  1722 . 2787276494_82703f570a.jpg ...
# Reading captions of  1723 . 2787276494_82703f570a.jpg ...
# Reading captions of  1724 . 2787276494_82703f570a.jpg ...
# Reading captions of  1725 . 2787276494_82703f570a.jpg ...
# Reading captions of  1726 . 2788945468_74a9618cfa.jpg ...
# Reading captions of  1727 . 2788945468_74a9618cfa.jpg ...
# Reading captions of  1728 . 2788945468_74a9618cfa.jpg ...
# Reading captions of  1729 . 2788945468_74a9618cfa.jpg ...
# Reading captions of  1730 . 2788945468_74a9618cfa.jpg ...
# Reading captions of  1731 . 2792195540_af5fb95caa.jpg ...
# Reading captions of  1732 . 2792195540_af5fb95caa.jpg ...
# Reading captions of  1733 . 2792195540_af5fb95caa.jpg ...
# Reading captions of  1734 . 2792195540_af5fb95caa.jpg ...
# Reading captions of  1735 . 2792195540_af5fb95caa.jpg ...
# Reading captions of  1736 . 2800758232_d7fa598065.jpg ...
# Reading captions of  1737 . 2800758232_d7fa598065.jpg ...
# Reading captions of  1738 . 2800758232_d7fa598065.jpg ...
# Reading captions of  1739 . 2800758232_d7fa598065.jpg ...
# Reading captions of  1740 . 2800758232_d7fa598065.jpg ...
# Reading captions of  1741 . 2800934095_b84a5009dd.jpg ...
# Reading captions of  1742 . 2800934095_b84a5009dd.jpg ...
# Reading captions of  1743 . 2800934095_b84a5009dd.jpg ...
# Reading captions of  1744 . 2800934095_b84a5009dd.jpg ...
# Reading captions of  1745 . 2800934095_b84a5009dd.jpg ...
# Reading captions of  1746 . 2802337003_56e555cd30.jpg ...
# Reading captions of  1747 . 2802337003_56e555cd30.jpg ...
# Reading captions of  1748 . 2802337003_56e555cd30.jpg ...
# Reading captions of  1749 . 2802337003_56e555cd30.jpg ...
# Reading captions of  1750 . 2802337003_56e555cd30.jpg ...
# Reading captions of  1751 . 2807177340_bc85291df5.jpg ...
# Reading captions of  1752 . 2807177340_bc85291df5.jpg ...
# Reading captions of  1753 . 2807177340_bc85291df5.jpg ...
# Reading captions of  1754 . 2807177340_bc85291df5.jpg ...
# Reading captions of  1755 . 2807177340_bc85291df5.jpg ...
# Reading captions of  1756 . 2813784259_d201044d71.jpg ...
# Reading captions of  1757 . 2813784259_d201044d71.jpg ...
# Reading captions of  1758 . 2813784259_d201044d71.jpg ...
# Reading captions of  1759 . 2813784259_d201044d71.jpg ...
# Reading captions of  1760 . 2813784259_d201044d71.jpg ...
# Reading captions of  1761 . 2815256108_fc1302117d.jpg ...
# Reading captions of  1762 . 2815256108_fc1302117d.jpg ...
# Reading captions of  1763 . 2815256108_fc1302117d.jpg ...
# Reading captions of  1764 . 2815256108_fc1302117d.jpg ...
# Reading captions of  1765 . 2815256108_fc1302117d.jpg ...
# Reading captions of  1766 . 2819254573_9ecb5f4d5e.jpg ...
# Reading captions of  1767 . 2819254573_9ecb5f4d5e.jpg ...
# Reading captions of  1768 . 2819254573_9ecb5f4d5e.jpg ...
# Reading captions of  1769 . 2819254573_9ecb5f4d5e.jpg ...
# Reading captions of  1770 . 2819254573_9ecb5f4d5e.jpg ...
# Reading captions of  1771 . 2823075967_be4c350e9e.jpg ...
# Reading captions of  1772 . 2823075967_be4c350e9e.jpg ...
# Reading captions of  1773 . 2823075967_be4c350e9e.jpg ...
# Reading captions of  1774 . 2823075967_be4c350e9e.jpg ...
# Reading captions of  1775 . 2823075967_be4c350e9e.jpg ...
# Reading captions of  1776 . 2824004868_1fc0a81173.jpg ...
# Reading captions of  1777 . 2824004868_1fc0a81173.jpg ...
# Reading captions of  1778 . 2824004868_1fc0a81173.jpg ...
# Reading captions of  1779 . 2824004868_1fc0a81173.jpg ...
# Reading captions of  1780 . 2824004868_1fc0a81173.jpg ...
# Reading captions of  1781 . 2831215155_07ba8f1805.jpg ...
# Reading captions of  1782 . 2831215155_07ba8f1805.jpg ...
# Reading captions of  1783 . 2831215155_07ba8f1805.jpg ...
# Reading captions of  1784 . 2831215155_07ba8f1805.jpg ...
# Reading captions of  1785 . 2831215155_07ba8f1805.jpg ...
# Reading captions of  1786 . 2831313661_1a328acb70.jpg ...
# Reading captions of  1787 . 2831313661_1a328acb70.jpg ...
# Reading captions of  1788 . 2831313661_1a328acb70.jpg ...
# Reading captions of  1789 . 2831313661_1a328acb70.jpg ...
# Reading captions of  1790 . 2831313661_1a328acb70.jpg ...
# Reading captions of  1791 . 2832978253_8fcc72da3b.jpg ...
# Reading captions of  1792 . 2832978253_8fcc72da3b.jpg ...
# Reading captions of  1793 . 2832978253_8fcc72da3b.jpg ...
# Reading captions of  1794 . 2832978253_8fcc72da3b.jpg ...
# Reading captions of  1795 . 2832978253_8fcc72da3b.jpg ...
# Reading captions of  1796 . 2833582518_074bef3ed6.jpg ...
# Reading captions of  1797 . 2833582518_074bef3ed6.jpg ...
# Reading captions of  1798 . 2833582518_074bef3ed6.jpg ...
# Reading captions of  1799 . 2833582518_074bef3ed6.jpg ...
# Reading captions of  1800 . 2833582518_074bef3ed6.jpg ...
# Reading captions of  1801 . 2836864045_9a093cfd65.jpg ...
# Reading captions of  1802 . 2836864045_9a093cfd65.jpg ...
# Reading captions of  1803 . 2836864045_9a093cfd65.jpg ...
# Reading captions of  1804 . 2836864045_9a093cfd65.jpg ...
# Reading captions of  1805 . 2836864045_9a093cfd65.jpg ...
# Reading captions of  1806 . 2837640996_0183db8d93.jpg ...
# Reading captions of  1807 . 2837640996_0183db8d93.jpg ...
# Reading captions of  1808 . 2837640996_0183db8d93.jpg ...
# Reading captions of  1809 . 2837640996_0183db8d93.jpg ...
# Reading captions of  1810 . 2837640996_0183db8d93.jpg ...
# Reading captions of  1811 . 2839038702_e168128665.jpg ...
# Reading captions of  1812 . 2839038702_e168128665.jpg ...
# Reading captions of  1813 . 2839038702_e168128665.jpg ...
# Reading captions of  1814 . 2839038702_e168128665.jpg ...
# Reading captions of  1815 . 2839038702_e168128665.jpg ...
# Reading captions of  1816 . 2847859796_4d9cb0d31f.jpg ...
# Reading captions of  1817 . 2847859796_4d9cb0d31f.jpg ...
# Reading captions of  1818 . 2847859796_4d9cb0d31f.jpg ...
# Reading captions of  1819 . 2847859796_4d9cb0d31f.jpg ...
# Reading captions of  1820 . 2847859796_4d9cb0d31f.jpg ...
# Reading captions of  1821 . 2848266893_9693c66275.jpg ...
# Reading captions of  1822 . 2848266893_9693c66275.jpg ...
# Reading captions of  1823 . 2848266893_9693c66275.jpg ...
# Reading captions of  1824 . 2848266893_9693c66275.jpg ...
# Reading captions of  1825 . 2848266893_9693c66275.jpg ...
# Reading captions of  1826 . 2851198725_37b6027625.jpg ...
# Reading captions of  1827 . 2851198725_37b6027625.jpg ...
# Reading captions of  1828 . 2851198725_37b6027625.jpg ...
# Reading captions of  1829 . 2851198725_37b6027625.jpg ...
# Reading captions of  1830 . 2851198725_37b6027625.jpg ...
# Reading captions of  1831 . 2854207034_1f00555703.jpg ...
# Reading captions of  1832 . 2854207034_1f00555703.jpg ...
# Reading captions of  1833 . 2854207034_1f00555703.jpg ...
# ...
# Reading features of  722 . 2764178773_d63b502812.jpg ...
# Reading features of  723 . 2751567262_e089b33ed9.jpg ...
# Reading features of  724 . 2755362721_368cbde668.jpg ...
# Reading features of  725 . 2763601657_09a52a063f.jpg ...
# Reading features of  726 . 2769731772_18c44c18e2.jpg ...
# Reading features of  727 . 276356412_dfa01c3c9e.jpg ...
# Reading features of  728 . 2747640247_b54bfa6886.jpg ...
# Reading features of  729 . 2720215226_5a98ff2bd3.jpg ...
# Reading features of  730 . 2743709828_a795a75bfc.jpg ...
# Reading features of  731 . 2735792721_b8fe85e803.jpg ...
# Reading features of  732 . 2742426734_291df6da08.jpg ...
# Reading features of  733 . 2714878018_1593c38d69.jpg ...
# Reading features of  734 . 2782433864_5a0c311d87.jpg ...
# Reading features of  735 . 2824004868_1fc0a81173.jpg ...
# Reading features of  736 . 2836864045_9a093cfd65.jpg ...
# Reading features of  737 . 2831215155_07ba8f1805.jpg ...
# Reading features of  738 . 2815256108_fc1302117d.jpg ...
# Reading features of  739 . 2807177340_bc85291df5.jpg ...
# Reading features of  740 . 2787276494_82703f570a.jpg ...
# Reading features of  741 . 2784625888_71a421e171.jpg ...
# Reading features of  742 . 2802337003_56e555cd30.jpg ...
# Reading features of  743 . 2800758232_d7fa598065.jpg ...
# Reading features of  744 . 278002800_3817135105.jpg ...
# Reading features of  745 . 2800934095_b84a5009dd.jpg ...
# Reading features of  746 . 2819254573_9ecb5f4d5e.jpg ...
# Reading features of  747 . 2813784259_d201044d71.jpg ...
# Reading features of  748 . 2785108434_cd4a1c949c.jpg ...
# Reading features of  749 . 2833582518_074bef3ed6.jpg ...
# Reading features of  750 . 2792195540_af5fb95caa.jpg ...
# Reading features of  751 . 2832978253_8fcc72da3b.jpg ...
# Reading features of  752 . 2788945468_74a9618cfa.jpg ...
# Reading features of  753 . 2831313661_1a328acb70.jpg ...
# Reading features of  754 . 2837640996_0183db8d93.jpg ...
# Reading features of  755 . 2774581025_81a3074e2e.jpg ...
# Reading features of  756 . 2823075967_be4c350e9e.jpg ...
# Reading features of  757 . 2851198725_37b6027625.jpg ...
# Reading features of  758 . 2860041212_797afd6ccf.jpg ...
# Reading features of  759 . 2198484810_50a893824a.jpg ...
# Reading features of  760 . 2195620255_6693479734.jpg ...
# Reading features of  761 . 2127031632_77505e4218.jpg ...
# Reading features of  762 . 2187904131_96ea83b9b5.jpg ...
# Reading features of  763 . 2138487671_5b89104043.jpg ...
# Reading features of  764 . 2190137367_746335f707.jpg ...
# Reading features of  765 . 2198511848_311d8a8c2f.jpg ...
# Reading features of  766 . 2178306830_6af49375b4.jpg ...
# Reading features of  767 . 2149982207_5345633bbf.jpg ...
# Reading features of  768 . 2196107384_361d73a170.jpg ...
# Reading features of  769 . 2200901777_f6c168bd32.jpg ...
# Reading features of  770 . 2139519215_8ca16dd192.jpg ...
# Reading features of  771 . 2120469056_7a738413be.jpg ...
# Reading features of  772 . 2136514643_93d8f75a77.jpg ...
# Reading features of  773 . 2203449950_e51d0f9065.jpg ...
# Reading features of  774 . 2194494220_bb2178832c.jpg ...
# Reading features of  775 . 2201978994_c444e64810.jpg ...
# Reading features of  776 . 2219959872_988e6d498e.jpg ...
# Reading features of  777 . 2248487956_2603f55ab9.jpg ...
# Reading features of  778 . 2225231022_1632d0a5aa.jpg ...
# Reading features of  779 . 2258951972_92763fddab.jpg ...
# Reading features of  780 . 2244613488_4d1f9edb33.jpg ...
# Reading features of  781 . 2220612655_030413b787.jpg ...
# Reading features of  782 . 2208310655_a3d83080c5.jpg ...
# Reading features of  783 . 2208055895_37cd8e1edf.jpg ...
# Reading features of  784 . 2220175999_081aa9cce8.jpg ...
# Reading features of  785 . 2256231539_05c27179f1.jpg ...
# Reading features of  786 . 2256138896_3e24b0b28d.jpg ...
# Reading features of  787 . 2257631407_1529b9db39.jpg ...
# Reading features of  788 . 2250555512_71670078f5.jpg ...
# Reading features of  789 . 2219805467_370ee1b7aa.jpg ...
# Reading features of  790 . 2246717855_c0c08fe5d2.jpg ...
# Reading features of  791 . 2219805677_7b7cc188c7.jpg ...
# Reading features of  792 . 2252299132_14ca6e584b.jpg ...
# Reading features of  793 . 2266061169_dfbf8f0595.jpg ...
# Reading features of  794 . 2265100168_175f8218af.jpg ...
# Reading features of  795 . 2234702530_a265a4df22.jpg ...
# Reading features of  796 . 233270519_d60d4518fa.jpg ...
# Reading features of  797 . 2297471897_3419605c16.jpg ...
# Reading features of  798 . 2318659263_c24005a5cb.jpg ...
# Reading features of  799 . 2315418282_80bd0bb1c0.jpg ...
# Reading features of  800 . 2303426046_09cfd7bc4e.jpg ...
# Reading features of  801 . 2303016989_0deb96c8d9.jpg ...
# Reading features of  802 . 2272489996_95b0a62d15.jpg ...
# Reading features of  803 . 2299859649_07ca44a222.jpg ...
# Reading features of  804 . 2286239223_d84ffc4e4a.jpg ...
# Reading features of  805 . 2319175397_3e586cfaf8.jpg ...
# Reading features of  806 . 2276314067_7ee246f859.jpg ...
# Reading features of  807 . 2289212650_69de7a20b2.jpg ...
# Reading features of  808 . 2300920203_f29260b1db.jpg ...
# Reading features of  809 . 2306186887_0bd8ed3792.jpg ...
# Reading features of  810 . 2312746782_4528a5b818.jpg ...
# Reading features of  811 . 2313230479_13f87c6bf3.jpg ...
# Reading features of  812 . 2324979199_4193ef7537.jpg ...
# Reading features of  813 . 2271890493_da441718ba.jpg ...
# Reading features of  814 . 2290589734_b588471345.jpg ...
# Reading features of  815 . 2286032269_8ba929709c.jpg ...
# Reading features of  816 . 2324779494_5e72d29171.jpg ...
# Reading features of  817 . 2325386353_1f1a05e1ce.jpg ...
# Reading features of  818 . 2288315705_5f4c37d932.jpg ...
# Reading features of  819 . 2363100645_c3423a0433.jpg ...
# Reading features of  820 . 2355578735_286af5b202.jpg ...
# Reading features of  821 . 2353119813_685bace18e.jpg ...
# Reading features of  822 . 2385146732_d1c67c790e.jpg ...
# Reading features of  823 . 2376878930_dd3e7cc544.jpg ...
# Reading features of  824 . 2395967330_7e6ea404f6.jpg ...
# Reading features of  825 . 2358554995_54ed3baa83.jpg ...
# Reading features of  826 . 2396691909_6b8c2f7c44.jpg ...
# Reading features of  827 . 2363540508_9dd1ccf7c7.jpg ...
# Reading features of  828 . 2405599120_ec5f32af6f.jpg ...
# Reading features of  829 . 2346523971_d3f1e12ce4.jpg ...
# Reading features of  830 . 2368266191_87d77750f1.jpg ...
# Reading features of  831 . 2340919359_f56787d307.jpg ...
# Reading features of  832 . 2404520067_87798dbaee.jpg ...
# Reading features of  833 . 2341254813_c53a5ef27a.jpg ...
# Reading features of  834 . 2393298349_e659308218.jpg ...
# Reading features of  835 . 2384147448_c1869070d3.jpg ...
# Reading features of  836 . 2343525685_3eba3b6686.jpg ...
# Reading features of  837 . 239453674_0df7767208.jpg ...
# Reading features of  838 . 237953705_cfe6999307.jpg ...
# Reading features of  839 . 241346885_f519ece460.jpg ...
# Reading features of  840 . 2432038587_5e4148e277.jpg ...
# Reading features of  841 . 241346508_0b3907a95b.jpg ...
# Reading features of  842 . 2431120202_b24fe2333a.jpg ...
# Reading features of  843 . 2436081047_bca044c1d3.jpg ...
# Reading features of  844 . 241346923_18bd84bea4.jpg ...
# Reading features of  845 . 2418191216_82711d5c5c.jpg ...
# Reading features of  846 . 241346580_b3c035d65c.jpg ...
# Reading features of  847 . 2443229844_277cded27d.jpg ...
# Reading features of  848 . 2429978680_1e18a13835.jpg ...
# Reading features of  849 . 2428959030_bdffc2812e.jpg ...
# Reading features of  850 . 2414397449_2ac3b78e0d.jpg ...
# Reading features of  851 . 2429729667_42effc165d.jpg ...
# Reading features of  852 . 2420546021_4a59790da6.jpg ...
# Reading features of  853 . 241347823_6b25c3e58e.jpg ...
# Reading features of  854 . 2410399168_1462c422d4.jpg ...
# Reading features of  855 . 2433175169_da939372f2.jpg ...
# Reading features of  856 . 2416964653_db3c2b6a0e.jpg ...
# Reading features of  857 . 2436398074_8737f40869.jpg ...
# Reading features of  858 . 2428275562_4bde2bc5ea.jpg ...
# Reading features of  859 . 241347356_8a515555fd.jpg ...
# Reading features of  860 . 2425262733_afe0718276.jpg ...
# Reading features of  861 . 2449289139_08fc1092c1.jpg ...
# Reading features of  862 . 2460126267_0deea8b645.jpg ...
# Reading features of  863 . 248858242_1c33c54ada.jpg ...
# Reading features of  864 . 2449518585_113dc4a8e5.jpg ...
# Reading features of  865 . 2456615908_59cdac6605.jpg ...
# Reading features of  866 . 2449446913_28fa5b7c75.jpg ...
# Reading features of  867 . 2460159430_71ab1aacfa.jpg ...
# Reading features of  868 . 2472980433_210ec62874.jpg ...
# Reading features of  869 . 2479652566_8f9fac8af5.jpg ...
# Reading features of  870 . 2450486758_a66fd296ea.jpg ...
# Reading features of  871 . 2461990494_c5ece064cc.jpg ...
# Reading features of  872 . 2480832276_fa55480ecb.jpg ...
# Reading features of  873 . 2451988767_244bff98d1.jpg ...
# Reading features of  874 . 2453990033_df53f0d8c8.jpg ...
# Reading features of  875 . 2461616306_3ee7ac1b4b.jpg ...
# Reading features of  876 . 2477623312_58e8e8c8af.jpg ...
# Reading features of  877 . 2485467050_1d5e2696d4.jpg ...
# Reading features of  878 . 2458269558_277012780d.jpg ...
# Reading features of  879 . 2497608431_8dfefc7a1a.jpg ...
# Reading features of  880 . 1143373711_2e90b7b799.jpg ...
# Reading features of  881 . 1118557877_736f339752.jpg ...
# Reading features of  882 . 1142847777_2a0c1c2551.jpg ...
# Reading features of  883 . 1144288288_e5c9558b6a.jpg ...
# Reading features of  884 . 1164765687_7aca07bbe7.jpg ...
# Reading features of  885 . 1131804997_177c3c0640.jpg ...
# Reading features of  886 . 109823397_e35154645f.jpg ...
# Reading features of  887 . 1229756013_94663527d7.jpg ...
# Reading features of  888 . 1167908324_8caab45e15.jpg ...
# Reading features of  889 . 10815824_2997e03d76.jpg ...
# Reading features of  890 . 1191338263_a4fa073154.jpg ...
# Reading features of  891 . 1231229740_8dcbf80bfb.jpg ...
# Reading features of  892 . 114051287_dd85625a04.jpg ...
# Reading features of  893 . 1295669416_21cabf594d.jpg ...
# Reading features of  894 . 1338523142_57fce8229b.jpg ...
# Reading features of  895 . 124972799_de706b6d0b.jpg ...
# Reading features of  896 . 1271960365_e54033f883.jpg ...
# Reading features of  897 . 1240297429_c36ae0c58f.jpg ...
# Reading features of  898 . 132489044_3be606baf7.jpg ...
# Reading features of  899 . 1260816604_570fc35836.jpg ...
# Reading features of  900 . 1311132744_5ffd03f831.jpg ...
# Reading features of  901 . 136886677_6026c622eb.jpg ...
# Reading features of  902 . 1287920676_d21a0b289b.jpg ...
# Reading features of  903 . 1368383637_614646cc4a.jpg ...
# Reading features of  904 . 1267711451_e2a754b4f8.jpg ...
# Reading features of  905 . 1259936608_e3f0064f23.jpg ...
# Reading features of  906 . 1312020846_5abb4a9be2.jpg ...
# Reading features of  907 . 1263801010_5c74bf1715.jpg ...
# Reading features of  908 . 1358892595_7a37c45788.jpg ...
# Reading features of  909 . 1294578091_2ad02fea91.jpg ...
# Reading features of  910 . 1248940539_46d33ed487.jpg ...
# Reading features of  911 . 1295671216_cde1b9c9d1.jpg ...
# Reading features of  912 . 1321723162_9d4c78b8af.jpg ...
# Reading features of  913 . 1363843090_9425d93064.jpg ...
# Reading features of  914 . 1303548017_47de590273.jpg ...
# Reading features of  915 . 1342780478_bacc32344d.jpg ...
# Reading features of  916 . 1443807993_aebfb2784a.jpg ...
# Reading features of  917 . 1476241331_2f43b67aed.jpg ...
# Reading features of  918 . 1448511770_1a4a9c453b.jpg ...
# Reading features of  919 . 1389264266_8170bc1c54.jpg ...
# Reading features of  920 . 143237785_93f81b3201.jpg ...
# Reading features of  921 . 1439282131_3814d6ae04.jpg ...
# Reading features of  922 . 146098876_0d99d7fb98.jpg ...
# Reading features of  923 . 1415591512_a84644750c.jpg ...
# Reading features of  924 . 1418019748_51c7d59c11.jpg ...
# Reading features of  925 . 1479028910_3dab3448c8.jpg ...
# Reading features of  926 . 1414820925_3504c394e1.jpg ...
# Reading features of  927 . 142802798_962a4ec5ce.jpg ...
# Reading features of  928 . 146100443_906d87faa2.jpg ...
# Reading features of  929 . 1394396709_65040d97ab.jpg ...
# Reading features of  930 . 1412832223_99e8b4701a.jpg ...
# Reading features of  931 . 1398606571_f543f7698a.jpg ...
# Reading features of  932 . 1432179046_8e3d75cf81.jpg ...
# Reading features of  933 . 1419286010_b59af3962a.jpg ...
# Reading features of  934 . 1463732807_0cdf4f22c7.jpg ...
# Reading features of  935 . 1721637099_93e9ec2a2f.jpg ...
# Reading features of  936 . 1479513774_70c94cf9d3.jpg ...
# Reading features of  937 . 1764955991_5e53a28c87.jpg ...
# Reading features of  938 . 1501297480_8db52c15b0.jpg ...
# Reading features of  939 . 1529044279_4922ead27c.jpg ...
# Reading features of  940 . 1581822598_0ae23074f1.jpg ...
# Reading features of  941 . 1561658940_a947f2446a.jpg ...
# Reading features of  942 . 1732436777_950bcdc9b8.jpg ...
# Reading features of  943 . 1488937076_5baa73fc2a.jpg ...
# Reading features of  944 . 162743064_bb242faa31.jpg ...
# Reading features of  945 . 166433861_70b66cd381.jpg ...
# Reading features of  946 . 161669933_3e7d8c7e2c.jpg ...
# Reading features of  947 . 1765164972_92dac06fa9.jpg ...
# Reading features of  948 . 1554713437_61b64527dd.jpg ...
# Reading features of  949 . 1689658980_0074d81d28.jpg ...
# Reading features of  950 . 2046222127_a6f300e202.jpg ...
# Reading features of  951 . 2052953131_30834196fb.jpg ...
# Reading features of  952 . 1860543210_47e94cf652.jpg ...
# Reading features of  953 . 2053777548_108e54c826.jpg ...
# Reading features of  954 . 2050067751_22d2763fd2.jpg ...
# Reading features of  955 . 1956678973_223cb1b847.jpg ...
# Reading features of  956 . 1785138090_76a56aaabc.jpg ...
# Reading features of  957 . 2045023435_181854c013.jpg ...
# Reading features of  958 . 1776981714_5b224d0f7a.jpg ...
# Reading features of  959 . 186890605_ddff5b694e.jpg ...
# Reading features of  960 . 1980882959_9a161f3469.jpg ...
# Reading features of  961 . 1795151944_d69b82f942.jpg ...
# Reading features of  962 . 2052202553_373dad145b.jpg ...
# Reading features of  963 . 191003284_1025b0fb7d.jpg ...
# Reading features of  964 . 1806580620_a8fe0fb9f8.jpg ...
# Reading features of  965 . 1876536922_8fdf8d7028.jpg ...
# Reading features of  966 . 2053733930_e245615ad4.jpg ...
# Reading features of  967 . 185972340_781d60ccfd.jpg ...
# Reading features of  968 . 1977827746_4e13d7e19f.jpg ...
# Reading features of  969 . 2092177624_13ab757e8b.jpg ...
# Reading features of  970 . 2094810449_f8df9dcdf7.jpg ...
# Reading features of  971 . 2077079696_03380d218b.jpg ...
# Reading features of  972 . 2055646179_169807fed4.jpg ...
# Reading features of  973 . 2085400856_ae09df33a7.jpg ...
# Reading features of  974 . 2071309418_1d7580b0f0.jpg ...
# Reading features of  975 . 211295363_49010ca38d.jpg ...
# Reading features of  976 . 2081679622_6f1442367d.jpg ...
# Reading features of  977 . 2070798293_6b9405e04d.jpg ...
# Reading features of  978 . 2112921744_92bf706805.jpg ...
# Reading features of  979 . 205682549_713aa6cd88.jpg ...
# Reading features of  980 . 2082005167_a0d6a70020.jpg ...
# Reading features of  981 . 2084217208_7bd9bc85e5.jpg ...
# Reading features of  982 . 2096771662_984441d20d.jpg ...
# Reading features of  983 . 2073174497_18b779999c.jpg ...
# Reading features of  984 . 2067362863_59577f9d4d.jpg ...
# Reading features of  985 . 2064417101_3b9d817f4a.jpg ...
# Reading features of  986 . 217838128_1f0a84ddc1.jpg ...
# Reading features of  987 . 2176147758_9a8deba576.jpg ...
# Reading features of  988 . 2120383553_5825333a3f.jpg ...
# Reading features of  989 . 2176980976_7054c99621.jpg ...
# Reading features of  990 . 2140747429_62cfd89ae9.jpg ...
# Reading features of  991 . 103195344_5d2dc613a3.jpg ...
# Reading features of  992 . 1012212859_01547e3f17.jpg ...
# Reading features of  993 . 103106960_e8a41d64f8.jpg ...
# Reading features of  994 . 101669240_b2d3e7f17b.jpg ...
# Reading features of  995 . 105342180_4d4a40b47f.jpg ...
# Reading features of  996 . 123889082_d3751e0350.jpg ...
# Reading features of  997 . 111537217_082a4ba060.jpg ...
# Reading features of  998 . 1234817607_924893f6e1.jpg ...
# Reading features of  999 . 1117972841_2b9261f95f.jpg ...
# Reading features of  1000 . 1177994172_10d143cb8d.jpg ...
# Total photo features available:  1000
# Loaded image features and corresponding captions in sequence successfully!

# %%
#6. Integration:
'''
from itertools import islice
def chunks(data, SIZE=10000):
    it = iter(data)
    for i in range(0, len(data), SIZE):
        yield {k:data[k] for k in islice(it, SIZE)}

if __name__ == '__main__':
#    training_generator=DataGenerator(map, tokenizer, max_length, photos, vocab_size,batch_size=2)
    inp_shape=photos[list(photos.keys())[0]].shape
    model=tf.keras.models.load_model('./models/a4_2/full_model')
#    model=build_model(vocab_size,max_length,inp_shape[1:],K=K)
    earlystop=keras.callbacks.EarlyStopping(monitor='val_loss',patience=max_patience)
#    print(len(map))
    rm=0
    for i in range(2):
        for item in chunks(map,1000):
            rm=rm+1
            if rm >= 4:
                imgs,txts,outs = create_sequences(tokenizer,max_length,item,photos,vocab_size)
#                model.fit([np.reshape(imgs,(imgs.shape[0],7,7,512)),txts],outs,epochs=5,validation_split=0.1,callbacks=[earlystop])
#                model.save('./models/a4_2/full_model')
#            model.fit([imgs,txts],outs,epochs=2)'Test_image.txt'):  #'image_names.txt'):
    #for i in range(1):
    #    earlystop=keras.callbacks.EarlyStopping(monitor='val_loss',patience=max_patience)
    
#        create_sequences(tokenizer, max_length, desc, photo, vocab_size)
#    generator=data_generator(map,photos,tokenizer,max_length,vocab_size)
#        inputs,outputs=next(generator)
#        print(inputs)
#        print(outputs)
#        print(inputs[1].shape,outputs.shape)
#    x,y,z=create_sequences(tokenizer,max_length,map,photos,vocab_size)
#    model.fit([x,y],z,epochs=max_epochs)
#    history=model.fit_generator(generator,epochs=1)

#    imgs,txts,outs=create_sequences(tokenizer,max_length,map,photos,vocab_size)
#    print(imgs.shape,txts.shape,outs.shape)
    #model=build_model(vocab_size,max_length,out_vgg16,K=K)
    #earlystop=keras.callbacks.EarlyStopping(monitor='val_loss',patience=max_patience)
    #model.fit([imgs,txts],outs,epochs=max_epochs,batch_size=batchsize,validation_split=val_split,callbacks=[earlystop])
'''
# Out:
# "\nfrom itertools import islice\ndef chunks(data, SIZE=10000):\n    it = iter(data)\n    for i in range(0, len(data), SIZE):\n        yield {k:data[k] for k in islice(it, SIZE)}\n\nif __name__ == '__main__':\n#    training_generator=DataGenerator(map, tokenizer, max_length, photos, vocab_size,batch_size=2)\n    inp_shape=photos[list(photos.keys())[0]].shape\n    model=tf.keras.models.load_model('./models/a4_2/full_model')\n#    model=build_model(vocab_size,max_length,inp_shape[1:],K=K)\n    earlystop=keras.callbacks.EarlyStopping(monitor='val_loss',patience=max_patience)\n#    print(len(map))\n    rm=0\n    for i in range(2):\n        for item in chunks(map,1000):\n            rm=rm+1\n            if rm >= 4:\n                imgs,txts,outs = create_sequences(tokenizer,max_length,item,photos,vocab_size)\n#                model.fit([np.reshape(imgs,(imgs.shape[0],7,7,512)),txts],outs,epochs=5,validation_split=0.1,callbacks=[earlystop])\n#                model.save('./models/a4_2/full_model')\n#            model.fit([imgs,txts],outs,epochs=2)'Test_image.txt'):  #'image_names.txt'):\n    #for i in range(1):\n    #    earlystop=keras.callbacks.EarlyStopping(monitor='val_loss',patience=max_patience)\n    \n#        create_sequences(tokenizer, max_length, desc, photo, vocab_size)\n#    generator=data_generator(map,photos,tokenizer,max_length,vocab_size)\n#        inputs,outputs=next(generator)\n#        print(inputs)\n#        print(outputs)\n#        print(inputs[1].shape,outputs.shape)\n#    x,y,z=create_sequences(tokenizer,max_length,map,photos,vocab_size)\n#    model.fit([x,y],z,epochs=max_epochs)\n#    history=model.fit_generator(generator,epochs=1)\n\n#    imgs,txts,outs=create_sequences(tokenizer,max_length,map,photos,vocab_size)\n#    print(imgs.shape,txts.shape,outs.shape)\n    #model=build_model(vocab_size,max_length,out_vgg16,K=K)\n    #earlystop=keras.callbacks.EarlyStopping(monitor='val_loss',patience=max_patience)\n    #model.fit([imgs,txts],outs,epochs=max_epochs,batch_size=batchsize,validation_split=val_split,callbacks=[earlystop])\n"

# %%
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None
 
# generate a description for an image
def generate_desc(model, tokenizer, photo, max_length):
	# seed the generation process
	in_text = 'startseq'
	# iterate over the whole length of the sequence
	for i in range(max_length):
		# integer encode input sequence
		sequence = tokenizer.texts_to_sequences([in_text])[0]
		# pad input
		sequence = pad_sequences([sequence], maxlen=max_length)
		# predict next word
		yhat = model.predict([photo,sequence], verbose=0)
		# convert probability to integer
		yhat = np.argmax(yhat)
		# map integer to word
		word = word_for_id(yhat, tokenizer)
		# stop if we cannot map the word
		if word is None:
			break
		# append as input for generating the next word
		in_text += ' ' + word
		# stop if we predict the end of the sequence
		if word == 'endseq':
			break
#	print('photo',photo)
	return in_text

# evaluate the skill of the model
def evaluate_model(model, descriptions, photos, tokenizer, max_length):
	actual, predicted = list(), list()
	# step over the whole set
	for key, desc_list in descriptions.items():
		# generate description
		yhat = generate_desc(model, tokenizer, photos[key], max_length)
		# store actual and predicted
		references = [d.split() for d in desc_list]
		actual.append(references)
		predicted.append(yhat.split())
#		print('key',key)
#		print('predicted',predicted[-1])
#		print('actual',actual[-1])
#		exit(0)
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0, 1.0, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0, 0, 1.0, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0, 0, 0, 1.0))) 
#	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
#	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
#	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
#	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25))) 

from nltk.translate.bleu_score import corpus_bleu
import tensorflow as tf
model=tf.keras.models.load_model('./models/a4_2/full_model')
evaluate_model(model,map,photos,tokenizer,max_length)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 34) for input Tensor("input_8:0", shape=(None, 34), dtype=float32), but it was called on an input with incompatible shape (None, 30).
# BLEU-1: 0.429108
# BLEU-2: 0.043094
# BLEU-3: 0.004611
# BLEU-4: 0.000668

# %%
#7. Plots of model results:
def plots(history):
    print(history.history.keys())
    plot.plot(history.history['accuracy'])
    plot.plot(history.history['val_accuracy'])
    plot.title('Model_Accuracy vs #Epochs')
    plot.ylabel('Accuracy')
    plot.xlabel('#Epochs')
    plot.legend(['Train', 'Test'], loc='upper right')
    plot.show()
    plot.plot(history.history['loss'])
    plot.plot(history.history['val_loss'])
    plot.title('Model_Loss (CrossEntropy) vs #Epochs')
    plot.ylabel('Loss')
    plot.xlabel('#Epochs')
    plot.legend(['Train', 'Test'], loc='upper right')
    plot.show()
#plots(history)
